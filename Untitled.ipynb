# %%
import pandas as pd
import time
start_time = time.time()

# %%
df = pd.read_csv("/Users/kashish/Downloads/dataset5.csv", header=None, delimiter=',', engine='python', names=range(100))
df = df.where((pd.notnull(df)), None)

# %%
df
# Out:
#           0            1            2     3       4     5     6         7   \
# 0   magzines  papertowels  heavy cream   Mop  lotion  Soap   tea  deodrant
# 1          t            t            t  None       t  None     t         t
# 2          t         None            t     t    None  None  None      None
# 3       None            t         None     t    None     t     t      None
# 4          t            t         None  None       t  None     t      None
# 5          t         None            t  None       t  None     t         t
# 6       None         None         None     t       t  None     t      None
# 7          t            t            t  None       t     t  None         t
# 8       None         None            t  None    None  None     t      None
# 9          t         None         None  None    None     t  None         t
# 10      None         None            t  None       t  None     t      None
# ...

# %%
ItemMatrix = \
    pd.get_dummies(df.unstack().dropna()).groupby(level=1).sum()
transactionCnt, itemCnt = ItemMatrix.shape
print('The number of transactions: ',transactionCnt)
print('The number of different items: ',itemCnt,'\n')
largeItemsets = []
for items in range(1, itemCnt+1):
    from itertools import combinations
    for itemset in combinations(ItemMatrix, items):
        itemset_Support = ItemMatrix[list(itemset)].all(axis=1).sum()
        s = [str(x) for x in itemset]
        if (len(s) >= 1):
            largeItemsets.append([",".join(s), itemset_Support])
freqItemset = pd.DataFrame(largeItemsets, columns=["Itemset", "Support"])
results = freqItemset[freqItemset.Support >= 2]
print(results)


dataFile = open('output.txt', 'w')

for eachitem in largeItemsets:
    dataFile.write(str(eachitem)+'\n')
dataFile.close()

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# The number of transactions:  29
# The number of different items:  21
